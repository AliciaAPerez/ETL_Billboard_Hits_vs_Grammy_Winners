# %%
import pandas as pd
from sqlalchemy import create_engine
import numpy as np
from datetime import timedelta, date
from config import key

# %% [markdown]
# <h1>Billboard Hot 100 Charts - 1999-2019</h1>

# %% [markdown]
# # Extracting DATA
# The data I gathered camed from https://www.kaggle.com/danield2255/data-on-songs-from-billboard-19992019 where it gave me a couple of CSV files to work with.

# %%
#the intiial data set
csv_file = "Resources/billboardHot100_1999-2019.csv"
billboard_data_df = pd.read_csv(csv_file)
billboard_data_df
# Out:
#        Unnamed: 0                       Artists                      Name  \
# 0               1                      Lil Nas,             Old Town Road
# 1               2  Shawn Mendes, Camila Cabello                  Senorita
# 2               3                 Billie Eilish                   Bad Guy
# 3               4                        Khalid                      Talk
# 4               5     Ed Sheeran, Justin Bieber              I Don't Care
# ...           ...                           ...                       ...
# 97220       97221                     Vitamin C                     Smile
# 97221       97222               Collective Soul                     Heavy
# 97222       97223         Mary Chapin Carpenter               Almost Home
# 97223       97224                             Q             Vivrant Thing
# 97224       97225                 The Offspring  Why Don't You Get A Job?
#
#        Weekly.rank  Peak.position  Weeks.on.chart        Week  \
# 0                1            1.0             7.0  2019-07-06
# 1                2            NaN             NaN  2019-07-06
# 2                3            2.0            13.0  2019-07-06
# 3                4            3.0            20.0  2019-07-06
# 4                5            2.0             7.0  2019-07-06
# ...            ...            ...             ...         ...
# 97220           95            NaN             NaN  1999-07-12
# 97221           96           73.0            20.0  1999-07-12
# 97222           97            NaN             NaN  1999-07-12
# 97223           98            NaN             NaN  1999-07-12
# 97224          100           74.0            15.0  1999-07-12
#
#                    Date                                              Genre  \
# 0         April 5, 2019  Country,Atlanta,Alternative Country,Hip-Hop,Tr...
# 1         June 21, 2019                                                Pop
# 2        March 29, 2019  Hip-Hop,Dark Pop,House,Trap,Memes,Alternative ...
# 3      February 7, 2019                                      Synth-Pop,Pop
# 4          May 10, 2019                      Canada,UK,Dance,Dance-Pop,Pop
# ...                 ...                                                ...
# 97220               NaN                                        Jamaica,Pop
# 97221               NaN                      Hockey,Gaming,Soundtrack,Rock
# 97222               NaN                                        Country,Pop
# 97223               NaN                                                Rap
# 97224               NaN                                 Ska,Punk Rock,Rock
#
#                                          Writing.Credits  \
# 0      Jozzy, Atticus ross, Trent reznor, Billy ray c...
# 1      Cashmere cat, Jack patterson, Charli xcx, Benn...
# 2                                 Billie eilish, Finneas
# 3                  Howard lawrence, Guy lawrence, Khalid
# 4      Ed sheeran, Justin bieber, Shellback, Max mart...
# ...                                                  ...
# 97220                  Colleen fitzpatrick, Josh deutsch
# 97221                                    Collective soul
# 97222  Annie roboff, Beth nielsen chapman, Mary chapi...
# 97223                        Q tip, J dilla, Barry white
# 97224                                     Dexter holland
#
#                                                   Lyrics         Features
# 0      Old Town Road Remix \nOh, oh-oh\nOh\nYeah, I'm...  Billy Ray Cyrus
# 1      Senorita \nI love it when you call me senorita...              NaN
# 2      bad guy \nWhite shirt now red, my bloody nose\...              NaN
# 3      Talk \nCan we just talk? Can we just talk?\nTa...              NaN
# 4      I Don't Care \nI'm at a party I don't wanna be...              NaN
# ...                                                  ...              ...
# 97220  Smile \nHahaha\nAlright, yeah\nAlright\nFirst ...         Lady Saw
# 97221  Heavy \nComplicate this world you wrapped for ...              NaN
# 97222  Almost Home \nI saw my life this morning\nLyin...              NaN
# 97223  Vivrant Thing \nUh check it out now\nUh no dou...              NaN
# 97224  Why Don't You Get a Job? \nMy friend's got a g...              NaN
#
# [97225 rows x 12 columns]

# %% [markdown]
#  # Transform DATA
#  I begin to look over and change the data into a format more useful for our project.

# %%
#Checking the Week type
billboard_data_df['Week']
# Out:
# 0        2019-07-06
# 1        2019-07-06
# 2        2019-07-06
# 3        2019-07-06
# 4        2019-07-06
#             ...
# 97220    1999-07-12
# 97221    1999-07-12
# 97222    1999-07-12
# 97223    1999-07-12
# 97224    1999-07-12
# Name: Week, Length: 97225, dtype: object

# %%
# Changing it from an object to a Date
billboard_data_df['Week'] = pd.to_datetime(billboard_data_df['Week'], errors='coerce')

# %%
billboard_data_df['Week']
# Out:
# 0       2019-07-06
# 1       2019-07-06
# 2       2019-07-06
# 3       2019-07-06
# 4       2019-07-06
#            ...
# 97220   1999-07-12
# 97221   1999-07-12
# 97222   1999-07-12
# 97223   1999-07-12
# 97224   1999-07-12
# Name: Week, Length: 97225, dtype: datetime64[ns]

# %%
billboard_data_df['Week'].dt.year >= 2010
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 97220    False
# 97221    False
# 97222    False
# 97223    False
# 97224    False
# Name: Week, Length: 97225, dtype: bool

# %%
billboard_years = billboard_data_df['Week'].dt.year >= 2010

# %%
billboard_years
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 97220    False
# 97221    False
# 97222    False
# 97223    False
# 97224    False
# Name: Week, Length: 97225, dtype: bool

# %%
# Changed the data to only show specific years
billboard_09to19_df = billboard_data_df[(billboard_data_df['Week'].dt.year >= 2009)]

# %%
billboard_09to19_df.head()
# Out:
#    Unnamed: 0                       Artists           Name  Weekly.rank  \
# 0           1                      Lil Nas,  Old Town Road            1
# 1           2  Shawn Mendes, Camila Cabello       Senorita            2
# 2           3                 Billie Eilish        Bad Guy            3
# 3           4                        Khalid           Talk            4
# 4           5     Ed Sheeran, Justin Bieber   I Don't Care            5
#
#    Peak.position  Weeks.on.chart       Week              Date  \
# 0            1.0             7.0 2019-07-06     April 5, 2019
# 1            NaN             NaN 2019-07-06     June 21, 2019
# 2            2.0            13.0 2019-07-06    March 29, 2019
# 3            3.0            20.0 2019-07-06  February 7, 2019
# 4            2.0             7.0 2019-07-06      May 10, 2019
#
#                                                Genre  \
# 0  Country,Atlanta,Alternative Country,Hip-Hop,Tr...
# 1                                                Pop
# 2  Hip-Hop,Dark Pop,House,Trap,Memes,Alternative ...
# 3                                      Synth-Pop,Pop
# 4                      Canada,UK,Dance,Dance-Pop,Pop
#
#                                      Writing.Credits  \
# 0  Jozzy, Atticus ross, Trent reznor, Billy ray c...
# 1  Cashmere cat, Jack patterson, Charli xcx, Benn...
# 2                             Billie eilish, Finneas
# 3              Howard lawrence, Guy lawrence, Khalid
# 4  Ed sheeran, Justin bieber, Shellback, Max mart...
#
#                                               Lyrics         Features
# 0  Old Town Road Remix \nOh, oh-oh\nOh\nYeah, I'm...  Billy Ray Cyrus
# 1  Senorita \nI love it when you call me senorita...              NaN
# 2  bad guy \nWhite shirt now red, my bloody nose\...              NaN
# 3  Talk \nCan we just talk? Can we just talk?\nTa...              NaN
# 4  I Don't Care \nI'm at a party I don't wanna be...              NaN

# %%
#started to clean it up more and dropped unused columns
cleaned_billboard_09to19 = billboard_09to19_df.drop(columns=['Unnamed: 0', 'Writing.Credits', 'Lyrics', 'Features'])

# %%
cleaned_billboard_09to19.head(102)
# Out:
#                           Artists                   Name  Weekly.rank  \
# 0                        Lil Nas,          Old Town Road            1
# 1    Shawn Mendes, Camila Cabello               Senorita            2
# 2                   Billie Eilish                Bad Guy            3
# 3                          Khalid                   Talk            4
# 4       Ed Sheeran, Justin Bieber           I Don't Care            5
# ..                            ...                    ...          ...
# 97                          Drake                 Omerta           99
# 98                  Martin Garrix            Summer Days          100
# 99                       Lil Nas,          Old Town Road            1
# 100                  Taylor Swift  You Need To Calm Down            2
# 101                 Billie Eilish                Bad Guy            3
#
#      Peak.position  Weeks.on.chart       Week              Date  \
# 0              1.0             7.0 2019-07-06     April 5, 2019
# 1              NaN             NaN 2019-07-06     June 21, 2019
# 2              2.0            13.0 2019-07-06    March 29, 2019
# 3              3.0            20.0 2019-07-06  February 7, 2019
# 4              2.0             7.0 2019-07-06      May 10, 2019
# ..             ...             ...        ...               ...
# 97            35.0             2.0 2019-07-06     June 15, 2019
# 98             NaN             NaN 2019-07-06    April 25, 2019
# 99             1.0             6.0 2019-06-29     April 5, 2019
# 100            NaN             NaN 2019-06-29     June 14, 2019
# 101            2.0            12.0 2019-06-29    March 29, 2019
#
#                                                  Genre
# 0    Country,Atlanta,Alternative Country,Hip-Hop,Tr...
# 1                                                  Pop
# 2    Hip-Hop,Dark Pop,House,Trap,Memes,Alternative ...
# 3                                        Synth-Pop,Pop
# 4                        Canada,UK,Dance,Dance-Pop,Pop
# ..                                                 ...
# 97                   Hip-Hop,Basketball,NBA,Canada,Rap
# 98   Electronic Pop,Electro,Electro House,Nederland...
# 99   Country,Atlanta,Alternative Country,Hip-Hop,Tr...
# 100                               Synth-Pop,LGBTQ+,Pop
# 101  Hip-Hop,Dark Pop,House,Trap,Memes,Alternative ...
#
# [102 rows x 8 columns]

# %% [markdown]
# ### Name changes
# The following lines are used to change the names of a couple of columns to use for the SQL table. Also to change a particular song and artist that was put in with the wrong information. Have some code lines to find the data to change and then change it to the actual information.

# %%
cleaned_billboard_09to19 = cleaned_billboard_09to19.rename(columns = {"Name":"song_title"})
cleaned_billboard_09to19 = cleaned_billboard_09to19.rename(columns = {"Weekly.rank":"weekly_rank"})
cleaned_billboard_09to19 = cleaned_billboard_09to19.rename(columns = {"Peak.position":"peak_posistion"})
cleaned_billboard_09to19 = cleaned_billboard_09to19.rename(columns = {"Weeks.on.chart":"weeks_on_chart"})
cleaned_billboard_09to19 = cleaned_billboard_09to19.rename(columns = {"Artists":"artists"})
cleaned_billboard_09to19 = cleaned_billboard_09to19.rename(columns = {"Song_Title":"song_title"})
cleaned_billboard_09to19 = cleaned_billboard_09to19.rename(columns = {"Date":"date"})
cleaned_billboard_09to19 = cleaned_billboard_09to19.rename(columns = {"Week":"week"})
cleaned_billboard_09to19 = cleaned_billboard_09to19.rename(columns = {"Genre":"genre"})
cleaned_billboard_09to19 = cleaned_billboard_09to19.replace({'song_title': r'^1'}, {'song_title': '1-800-273-8255'}, regex=True)
cleaned_billboard_09to19 = cleaned_billboard_09to19.replace({'artists': r'^800'}, {'artists': 'Logic'}, regex=True)
cleaned_billboard_09to19.loc[cleaned_billboard_09to19['song_title']=='1-800-273-8255']
# Out:
#       artists      song_title  weekly_rank  peak_posistion  weeks_on_chart  \
# 6984    Logic  1-800-273-8255           45             3.0            42.0
# 7078    Logic  1-800-273-8255           40             3.0            41.0
# 7170    Logic  1-800-273-8255           33             3.0            40.0
# 7281    Logic  1-800-273-8255           46             3.0            39.0
# 7376    Logic  1-800-273-8255           45             3.0            38.0
# 7471    Logic  1-800-273-8255           44             3.0            37.0
# 7556    Logic  1-800-273-8255           33             3.0            36.0
# 7653    Logic  1-800-273-8255           34             3.0            35.0
# 7736    Logic  1-800-273-8255           22             3.0            33.0
# 7831    Logic  1-800-273-8255           19             3.0            32.0
# 7924    Logic  1-800-273-8255           14             3.0            31.0
# 8020    Logic  1-800-273-8255           13             3.0            30.0
# 8114    Logic  1-800-273-8255            8             3.0            29.0
# 8211    Logic  1-800-273-8255            6             3.0            28.0
# 8307    Logic  1-800-273-8255            4             3.0            27.0
# 8403    Logic  1-800-273-8255            3             3.0            26.0
# 8501    Logic  1-800-273-8255            3             3.0            25.0
# 8599    Logic  1-800-273-8255            3             3.0            24.0
# 8698    Logic  1-800-273-8255            4             3.0            23.0
# 8797    Logic  1-800-273-8255            4             3.0            22.0
# 8896    Logic  1-800-273-8255            4             3.0            21.0
# 8994    Logic  1-800-273-8255            3             3.0            20.0
# 9094    Logic  1-800-273-8255            5             5.0            19.0
# 9197    Logic  1-800-273-8255            9             9.0            18.0
# 9316    Logic  1-800-273-8255           29            29.0            17.0
# 9423    Logic  1-800-273-8255           37            37.0            16.0
# 9534    Logic  1-800-273-8255           50            47.0            15.0
# 9635    Logic  1-800-273-8255           52            47.0            14.0
# 9738    Logic  1-800-273-8255           57            47.0            13.0
# 9834    Logic  1-800-273-8255           55            47.0            12.0
# 9939    Logic  1-800-273-8255           61            47.0            11.0
# 10042   Logic  1-800-273-8255           64            47.0            10.0
# 10142   Logic  1-800-273-8255           64            47.0             9.0
# 10245   Logic  1-800-273-8255           68            47.0             8.0
# 10343   Logic  1-800-273-8255           68            47.0             7.0
# 10438   Logic  1-800-273-8255           65            47.0             6.0
# 10533   Logic  1-800-273-8255           62            47.0             5.0
# 10632   Logic  1-800-273-8255           63            47.0             4.0
# 10730   Logic  1-800-273-8255           64            47.0             3.0
# 10811   Logic  1-800-273-8255           47            47.0             2.0
# 10923   Logic  1-800-273-8255           61             NaN             NaN
#
#             week            date                       genre
# 6984  2018-02-24  April 28, 2017  Hip-Hop,Canada,DMV,Pop,Rap
# 7078  2018-02-17  April 28, 2017  Hip-Hop,Canada,DMV,Pop,Rap
# 7170  2018-02-10  April 28, 2017  Hip-Hop,Canada,DMV,Pop,Rap
# 7281  2018-02-03  April 28, 2017  Hip-Hop,Canada,DMV,Pop,Rap
# 7376  2018-01-27  April 28, 2017  Hip-Hop,Canada,DMV,Pop,Rap
# 7471  2018-01-20  April 28, 2017  Hip-Hop,Canada,DMV,Pop,Rap
# 7556  2018-01-13  April 28, 2017  Hip-Hop,Canada,DMV,Pop,Rap
# 7653  2018-01-06  April 28, 2017  Hip-Hop,Canada,DMV,Pop,Rap
# 7736  2017-12-30  April 28, 2017  Hip-Hop,Canada,DMV,Pop,Rap
# 7831  2017-12-23  April 28, 2017  Hip-Hop,Canada,DMV,Pop,Rap
# 7924  2017-12-16  April 28, 2017  Hip-Hop,Canada,DMV,Pop,Rap
# 8020  2017-12-09  April 28, 2017  Hip-Hop,Canada,DMV,Pop,Rap
# 8114  2017-12-02  April 28, 2017  Hip-Hop,Canada,DMV,Pop,Rap
# 8211  2017-11-25  April 28, 2017  Hip-Hop,Canada,DMV,Pop,Rap
# 8307  2017-11-18  April 28, 2017  Hip-Hop,Canada,DMV,Pop,Rap
# 8403  2017-11-11  April 28, 2017  Hip-Hop,Canada,DMV,Pop,Rap
# 8501  2017-11-04  April 28, 2017  Hip-Hop,Canada,DMV,Pop,Rap
# 8599  2017-10-28  April 28, 2017  Hip-Hop,Canada,DMV,Pop,Rap
# 8698  2017-10-21  April 28, 2017  Hip-Hop,Canada,DMV,Pop,Rap
# 8797  2017-10-14  April 28, 2017  Hip-Hop,Canada,DMV,Pop,Rap
# 8896  2017-10-07  April 28, 2017  Hip-Hop,Canada,DMV,Pop,Rap
# 8994  2017-09-30  April 28, 2017  Hip-Hop,Canada,DMV,Pop,Rap
# 9094  2017-09-23  April 28, 2017  Hip-Hop,Canada,DMV,Pop,Rap
# 9197  2017-09-16  April 28, 2017  Hip-Hop,Canada,DMV,Pop,Rap
# 9316  2017-09-09  April 28, 2017  Hip-Hop,Canada,DMV,Pop,Rap
# 9423  2017-09-02  April 28, 2017  Hip-Hop,Canada,DMV,Pop,Rap
# 9534  2017-08-26  April 28, 2017  Hip-Hop,Canada,DMV,Pop,Rap
# 9635  2017-08-19  April 28, 2017  Hip-Hop,Canada,DMV,Pop,Rap
# 9738  2017-08-12  April 28, 2017  Hip-Hop,Canada,DMV,Pop,Rap
# 9834  2017-08-05  April 28, 2017  Hip-Hop,Canada,DMV,Pop,Rap
# 9939  2017-07-29  April 28, 2017  Hip-Hop,Canada,DMV,Pop,Rap
# 10042 2017-07-22  April 28, 2017  Hip-Hop,Canada,DMV,Pop,Rap
# 10142 2017-07-15  April 28, 2017  Hip-Hop,Canada,DMV,Pop,Rap
# 10245 2017-07-08  April 28, 2017  Hip-Hop,Canada,DMV,Pop,Rap
# 10343 2017-07-01  April 28, 2017  Hip-Hop,Canada,DMV,Pop,Rap
# 10438 2017-06-24  April 28, 2017  Hip-Hop,Canada,DMV,Pop,Rap
# 10533 2017-06-17  April 28, 2017  Hip-Hop,Canada,DMV,Pop,Rap
# 10632 2017-06-10  April 28, 2017  Hip-Hop,Canada,DMV,Pop,Rap
# 10730 2017-06-03  April 28, 2017  Hip-Hop,Canada,DMV,Pop,Rap
# 10811 2017-05-27  April 28, 2017  Hip-Hop,Canada,DMV,Pop,Rap
# 10923 2017-05-20  April 28, 2017  Hip-Hop,Canada,DMV,Pop,Rap

# %%
cleaned_billboard_09to19
# Out:
#                             artists                      song_title  \
# 0                          Lil Nas,                   Old Town Road
# 1      Shawn Mendes, Camila Cabello                        Senorita
# 2                     Billie Eilish                         Bad Guy
# 3                            Khalid                            Talk
# 4         Ed Sheeran, Justin Bieber                    I Don't Care
# ...                             ...                             ...
# 51875                       Beyonce                            Diva
# 51876                       Bobby V                            Beep
# 51877                  Randy Houser                   Anything Goes
# 51878                           The              Rockin' That Thang
# 51879                 Darius Rucker  It Won't Be Like This For Long
#
#        weekly_rank  peak_posistion  weeks_on_chart       week  \
# 0                1             1.0             7.0 2019-07-06
# 1                2             NaN             NaN 2019-07-06
# 2                3             2.0            13.0 2019-07-06
# 3                4             3.0            20.0 2019-07-06
# 4                5             2.0             7.0 2019-07-06
# ...            ...             ...             ...        ...
# 51875           96             NaN             NaN 2009-01-01
# 51876           97             NaN             NaN 2009-01-01
# 51877           98            92.0             5.0 2009-01-01
# 51878           99             NaN             NaN 2009-01-01
# 51879          100             NaN             NaN 2009-01-01
#
#                    date                                              genre
# 0         April 5, 2019  Country,Atlanta,Alternative Country,Hip-Hop,Tr...
# 1         June 21, 2019                                                Pop
# 2        March 29, 2019  Hip-Hop,Dark Pop,House,Trap,Memes,Alternative ...
# 3      February 7, 2019                                      Synth-Pop,Pop
# 4          May 10, 2019                      Canada,UK,Dance,Dance-Pop,Pop
# ...                 ...                                                ...
# 51875  January 20, 2009                                       Rap,R&;B,Pop
# 51876  October 27, 2008                                           R&;B,Pop
# 51877      June 2, 2008                                            Country
# 51878  December 9, 2008                                               R&;B
# 51879               NaN                                       Country,Rock
#
# [51880 rows x 8 columns]

# %%
# Saved the new dataframe into a CSV file
cleaned_billboard_09to19.to_csv("Resources/cleaned_billboardHot100_2009-2019.csv", index=False, header=True)

# %% [markdown]
# # Loading the Data into SQL
# The table for the data has been set up in pgAdmin in a database called "music_DB" with a table called billboard. Added the data and checked to see that it loaded properly.

# %%
# Connect to the datbase

#rds_connection_string = key
rds_connection_string = f"{key}@localhost:5432/music_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
# Check to see Table names

engine.table_names()
# Out:
# ['grammys', 'spotify', 'billboard']

# %%
# Add the data to the database
cleaned_billboard_09to19.to_sql('billboard', engine, if_exists='replace', index=False)

# %% [markdown]
# <h1>Grammy Data</h1>

# %% [markdown]
# <h2>Extract</h2>

# %% [markdown]
# Since future analysis would like to look at the correlation between popularity (as shown in the Billboard and Spotify charts) and critical success, we will be using Grammy awards from 2009 through 2019 as a measure of critical success.  Originally, we had planned to scrape the data from the Grammys official website (https://www.grammy.com/).  However, that website does not show nominations, only winners, for previous years.  We were able to identify an additional source to potentially scrape data from, Wikipedia, where pages exist for each year the Grammys were awarded.  However, attempts to scrape these pages were not successful due to generic labels that would have required far more work than we had time for.  We were able to identify a Kaggle dataset that supplied the required information (https://www.kaggle.com/unanimad/grammy-awards).  The compiler of this dataset took the data from the Grammy awards list and the IMDb database (details as to how that was accomplished were not given).
#
# The fields in the single .csv file of the dataset are:

# %% [markdown]
#     - year - year of award/nomination
#     - title - name of the award show and its year
#     - published_at
#     - updated_at
#     - category - category of the award
#     - nominee - the song, album, or artist nominated or awarded
#     - artist - the person(s) or groups responsible for the song or album.  Blank if category was for artist award.
#     - workers - addition people who worked on the nominee

# %%
#Create data frame from csv file.
grammy_csv = "Resources/the_grammy_awards.csv"

grammy_df = pd.read_csv(grammy_csv)
grammy_df.head()
# Out:
#    year                              title               published_at  \
# 0  2019  62nd Annual GRAMMY Awards  (2019)  2020-05-19T05:10:28-07:00
# 1  2019  62nd Annual GRAMMY Awards  (2019)  2020-05-19T05:10:28-07:00
# 2  2019  62nd Annual GRAMMY Awards  (2019)  2020-05-19T05:10:28-07:00
# 3  2019  62nd Annual GRAMMY Awards  (2019)  2020-05-19T05:10:28-07:00
# 4  2019  62nd Annual GRAMMY Awards  (2019)  2020-05-19T05:10:28-07:00
#
#                   updated_at            category     nominee         artist  \
# 0  2020-05-19T05:10:28-07:00  Record Of The Year     Bad Guy  Billie Eilish
# 1  2020-05-19T05:10:28-07:00  Record Of The Year     Hey, Ma       Bon Iver
# 2  2020-05-19T05:10:28-07:00  Record Of The Year     7 rings  Ariana Grande
# 3  2020-05-19T05:10:28-07:00  Record Of The Year  Hard Place         H.E.R.
# 4  2020-05-19T05:10:28-07:00  Record Of The Year        Talk         Khalid
#
#                                              workers  \
# 0  Finneas O'Connell, producer; Rob Kinelski & Fi...
# 1  BJ Burton, Brad Cook, Chris Messina & Justin V...
# 2  Charles Anderson, Tommy Brown, Michael Foster ...
# 3  Rodney “Darkchild” Jerkins, producer; Joseph H...
# 4  Disclosure & Denis Kosiak, producers; Ingmar C...
#
#                                                  img  winner
# 0  https://www.grammy.com/sites/com/files/styles/...    True
# 1  https://www.grammy.com/sites/com/files/styles/...    True
# 2  https://www.grammy.com/sites/com/files/styles/...    True
# 3  https://www.grammy.com/sites/com/files/styles/...    True
# 4  https://www.grammy.com/sites/com/files/styles/...    True

# %% [markdown]
# <h2>Transform</h2>

# %% [markdown]
# The data set includes several fields that are not necessary, including "title" (a reference to the title of the Grammy award show), "published_at", "updated_at", and "img".  In addition, the "winner" field is not accurate in this dataset as all rows show as "True".  We are dropping it for now.

# %%
# Drop unnecessary columns. Winner will be added back later.
grammy_df.drop(['title', 'published_at', 'updated_at', 'img', 'winner'], axis=1, inplace=True)
grammy_df
# Out:
#       year                                           category  \
# 0     2019                                 Record Of The Year
# 1     2019                                 Record Of The Year
# 2     2019                                 Record Of The Year
# 3     2019                                 Record Of The Year
# 4     2019                                 Record Of The Year
# ...    ...                                                ...
# 4805  1958  Best Classical Performance - Instrumentalist (...
# 4806  1958  Best Classical Performance - Instrumentalist (...
# 4807  1958  Best Classical Performance - Chamber Music (In...
# 4808  1958  Best Classical Performance - Vocal Soloist (Wi...
# 4809  1958    Best Classical Performance - Operatic Or Choral
#
#                                                 nominee         artist  \
# 0                                               Bad Guy  Billie Eilish
# 1                                               Hey, Ma       Bon Iver
# 2                                               7 rings  Ariana Grande
# 3                                            Hard Place         H.E.R.
# 4                                                  Talk         Khalid
# ...                                                 ...            ...
# 4805  Tchaikovsky: Piano Concerto No. 1 In B Flat Mi...            NaN
# 4806                             Segovia Golden Jubilee            NaN
# 4807                             Beethoven: Quartet 130            NaN
# 4808                                   Operatic Recital            NaN
# 4809                                           Virtuoso            NaN
#
#                                                 workers
# 0     Finneas O'Connell, producer; Rob Kinelski & Fi...
# 1     BJ Burton, Brad Cook, Chris Messina & Justin V...
# 2     Charles Anderson, Tommy Brown, Michael Foster ...
# 3     Rodney “Darkchild” Jerkins, producer; Joseph H...
# 4     Disclosure & Denis Kosiak, producers; Ingmar C...
# ...                                                 ...
# 4805  Van Cliburn, artist (Symphony Of The Air Orche...
# 4806                             Andres Segovia, artist
# 4807  Hollywood String Quartet (Alvin Dinkin, Paul S...
# 4808                                                NaN
# 4809                       Roger Wagner, choir director
#
# [4810 rows x 5 columns]

# %% [markdown]
# Because the data in other tables have limited timeframe, we limit the data to only the last ten years of awards (2009 - 2019).

# %%
# Drop all rows pre-2009 (first year of our Billboard database)
# Convert year to integer 
grammy_df['year'] = grammy_df['year'].astype(str).astype(int) 
clean_grammy_df = grammy_df.loc[grammy_df['year'] > 2008, :]
clean_grammy_df
# Out:
#       year                                 category  \
# 0     2019                       Record Of The Year
# 1     2019                       Record Of The Year
# 2     2019                       Record Of The Year
# 3     2019                       Record Of The Year
# 4     2019                       Record Of The Year
# ...    ...                                      ...
# 1314  2009         Best Classical Vocal Performance
# 1315  2009  Best Classical Contemporary Composition
# 1316  2009           Best Classical Crossover Album
# 1317  2009              Best Short Form Music Video
# 1318  2009               Best Long Form Music Video
#
#                                          nominee                      artist  \
# 0                                        Bad Guy               Billie Eilish
# 1                                        Hey, Ma                    Bon Iver
# 2                                        7 rings               Ariana Grande
# 3                                     Hard Place                      H.E.R.
# 4                                           Talk                      Khalid
# ...                                          ...                         ...
# 1314                               Verismo Arias                         NaN
# 1315       Higdon, Jennifer: Percussion Concerto                         NaN
# 1316  Yo-Yo Ma & Friends: Songs Of Joy And Peace  Yo-Yo Ma & Various Artists
# 1317                               Boom Boom Pow         The Black Eyed Peas
# 1318         The Beatles Love - All Together Now           (Various Artists)
#
#                                                 workers
# 0     Finneas O'Connell, producer; Rob Kinelski & Fi...
# 1     BJ Burton, Brad Cook, Chris Messina & Justin V...
# 2     Charles Anderson, Tommy Brown, Michael Foster ...
# 3     Rodney “Darkchild” Jerkins, producer; Joseph H...
# 4     Disclosure & Denis Kosiak, producers; Ingmar C...
# ...                                                 ...
# 1314  Renée Fleming, soloist; David Frost, producer;...
# 1315                          Jennifer Higdon, composer
# 1316  Steven Epstein, producer; Richard King, engine...
# 1317  Mathew Cullen & Mark Kudsi, video directors; J...
# 1318  Adrian Wills, video director; Martin Bolduc & ...
#
# [1319 rows x 5 columns]

# %% [markdown]
# As mentioned earlier, it appears that the compiler incorrectly marked everyone a winner for all awards. This is obviously incorrect. Comparing to the Wikipedia sites for each year, it seems that the first record for each award for each year is the winner, and the rest are the remaining nominees. Thus, we need to correct the data in winner column to reflect this. We deleted this column above, and will now add it back with the correct data.

# %%
# Declare variable to hold current award name to know when it changes
award = ''

# Declare a list that holds True or False
winner_list = []

# Go through the grammy dataframe, storing appropriate value in winner_list we can later use.
for index, row in clean_grammy_df.iterrows():
    # if the current row is not equal to the stored award, keep the True in winner and change the value of award
    if row['category'] != award:
        award = row['category']
        winner_list.append(True)
    else: 
        winner_list.append(False)

winner_list
# Out:
# [True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  ...]

# %%
# Using winner_list, let's update the clean_grammy_df winner column by merging

clean_grammy_df['winner'] = winner_list
clean_grammy_df
# Out:
# <ipython-input-23-fe13c3bda07c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_grammy_df['winner'] = winner_list
#       year                                 category  \
# 0     2019                       Record Of The Year
# 1     2019                       Record Of The Year
# 2     2019                       Record Of The Year
# 3     2019                       Record Of The Year
# 4     2019                       Record Of The Year
# ...    ...                                      ...
# 1314  2009         Best Classical Vocal Performance
# 1315  2009  Best Classical Contemporary Composition
# 1316  2009           Best Classical Crossover Album
# 1317  2009              Best Short Form Music Video
# 1318  2009               Best Long Form Music Video
#
#                                          nominee                      artist  \
# 0                                        Bad Guy               Billie Eilish
# 1                                        Hey, Ma                    Bon Iver
# 2                                        7 rings               Ariana Grande
# 3                                     Hard Place                      H.E.R.
# 4                                           Talk                      Khalid
# ...                                          ...                         ...
# 1314                               Verismo Arias                         NaN
# 1315       Higdon, Jennifer: Percussion Concerto                         NaN
# 1316  Yo-Yo Ma & Friends: Songs Of Joy And Peace  Yo-Yo Ma & Various Artists
# 1317                               Boom Boom Pow         The Black Eyed Peas
# 1318         The Beatles Love - All Together Now           (Various Artists)
#
#                                                 workers  winner
# 0     Finneas O'Connell, producer; Rob Kinelski & Fi...    True
# 1     BJ Burton, Brad Cook, Chris Messina & Justin V...   False
# 2     Charles Anderson, Tommy Brown, Michael Foster ...   False
# 3     Rodney “Darkchild” Jerkins, producer; Joseph H...   False
# 4     Disclosure & Denis Kosiak, producers; Ingmar C...   False
# ...                                                 ...     ...
# 1314  Renée Fleming, soloist; David Frost, producer;...    True
# 1315                          Jennifer Higdon, composer    True
# 1316  Steven Epstein, producer; Richard King, engine...    True
# 1317  Mathew Cullen & Mark Kudsi, video directors; J...    True
# 1318  Adrian Wills, video director; Martin Bolduc & ...    True
#
# [1319 rows x 6 columns]

# %%
# Save the file for other group members
clean_grammy_df.to_csv('grammys_clean.csv')

# %% [markdown]
# <h2>Load</h2>

# %% [markdown]
# Utilizing the above connection to the postgres, the cleaned dataframe was loaded into a table called "grammys".  This table will then be joined at the end utilizing the "nominee" and "artist" fields for the joins.

# %%
# Establish connection to postgres for saving data later.
# rds_connection_string = f"{key}@localhost:5432/music_db"
# engine = create_engine(f'postgresql://{rds_connection_string}')
# connection = engine.connect()

# %%
# Load dataframe as table to Postgres, using connection from above
clean_grammy_df.to_sql('grammys', engine, if_exists='replace',index=False) #drops old table and creates new empty table

# %%
pd.read_sql_query('select * from grammys', con=engine).head()
# Out:
#    year            category     nominee         artist  \
# 0  2019  Record Of The Year     Bad Guy  Billie Eilish
# 1  2019  Record Of The Year     Hey, Ma       Bon Iver
# 2  2019  Record Of The Year     7 rings  Ariana Grande
# 3  2019  Record Of The Year  Hard Place         H.E.R.
# 4  2019  Record Of The Year        Talk         Khalid
#
#                                              workers  winner
# 0  Finneas O'Connell, producer; Rob Kinelski & Fi...    True
# 1  BJ Burton, Brad Cook, Chris Messina & Justin V...   False
# 2  Charles Anderson, Tommy Brown, Michael Foster ...   False
# 3  Rodney “Darkchild” Jerkins, producer; Joseph H...   False
# 4  Disclosure & Denis Kosiak, producers; Ingmar C...   False

# %% [markdown]
# <h1>Spotify Data</h1>

# %% [markdown]
# ## Extracting the Data

# %% [markdown]
# ### Data Source
# https://www.kaggle.com/yamaerenay/spotify-dataset-19212020-160k-tracks
#
# This data set on Kaggle has 5 csv files, but only the first data set is used. It has song information on music released from 1921 to 2020 that is available on Spotify. It does not include any sort of ranking or number of plays; it is data for the song itself which includes the characteristics or attributes of the song. From the link, we can see what the creator intended for each of the categories and how to parse their data:
#     - id (Id of track generated by Spotify)
#     - acousticness (Ranges from 0 to 1)
#     - danceability (Ranges from 0 to 1)
#     - energy (Ranges from 0 to 1)
#     - duration_ms (Integer typically ranging from 200k to 300k)
#     - instrumentalness (Ranges from 0 to 1)
#     - valence (Ranges from 0 to 1)
#     - popularity (Ranges from 0 to 100)
#     - tempo (Float typically ranging from 50 to 150)
#     - liveness (Ranges from 0 to 1)
#     - loudness (Float typically ranging from -60 to 0)
#     - speechiness (Ranges from 0 to 1)
#     - year (Ranges from 1921 to 2020)
#     - mode (0 = Minor, 1 = Major)
#     - explicit (0 = No explicit content, 1 = Explicit content)
#     - key (All keys on octave encoded as values ranging from 0 to 11, starting on C as 0, C# as 1 and so on…)
#     - artists (List of artists mentioned)
#     - release_date (Date of release mostly in yyyy-mm-dd format, however precision of date may vary)
#     - name (Name of the song)
#
# All of that information was pulled from the Spotify API, and more information can be found here:
# https://developer.spotify.com/documentation/web-api/reference/#endpoint-get-audio-features

# %%
spotify_path = "Resources/data.csv"
spotify_data = pd.read_csv(spotify_path)
spotify_data
# Out:
#         acousticness                             artists  danceability  \
# 0           0.991000                     ['Mamie Smith']         0.598
# 1           0.643000           ["Screamin' Jay Hawkins"]         0.852
# 2           0.993000                     ['Mamie Smith']         0.647
# 3           0.000173                 ['Oscar Velazquez']         0.730
# 4           0.295000                            ['Mixe']         0.704
# ...              ...                                 ...           ...
# 174384      0.009170  ['DJ Combo', 'Sander-7', 'Tony T']         0.792
# 174385      0.795000                    ['Alessia Cara']         0.429
# 174386      0.806000                       ['Roger Fly']         0.671
# 174387      0.920000                    ['Taylor Swift']         0.462
# 174388      0.239000                       ['Roger Fly']         0.677
#
#         duration_ms  energy  explicit                      id  \
# 0            168333   0.224         0  0cS0A1fUEUd1EW3FcF8AEI
# 1            150200   0.517         0  0hbkKFIJm7Z05H8Zl9w30f
# 2            163827   0.186         0  11m7laMUgmOKqI3oYzuhne
# 3            422087   0.798         0  19Lc5SfJJ5O1oaxY0fpwfh
# 4            165224   0.707         1  2hJjbsLCytGsnAHfdsLejp
# ...             ...     ...       ...                     ...
# 174384       147615   0.866         0  46LhBf6TvYjZU2SMvGZAbn
# 174385       144720   0.211         0  7tue2Wemjd0FZzRtDrQFZd
# 174386       218147   0.589         0  48Qj61hOdYmUCFJbpQ29Ob
# 174387       244000   0.240         1  1gcyHQpBQ1lfXGdhZmWrHP
# 174388       197710   0.460         0  57tgYkWQTNHVFEt6xDKKZj
#
#         instrumentalness  key  liveness  loudness  mode  \
# 0               0.000522    5    0.3790   -12.628     0
# 1               0.026400    5    0.0809    -7.261     0
# 2               0.000018    0    0.5190   -12.098     1
# 3               0.801000    2    0.1280    -7.311     1
# 4               0.000246   10    0.4020    -6.036     0
# ...                  ...  ...       ...       ...   ...
# 174384          0.000060    6    0.1780    -5.089     0
# 174385          0.000000    4    0.1960   -11.665     1
# 174386          0.920000    4    0.1130   -12.393     0
# 174387          0.000000    0    0.1130   -12.077     1
# 174388          0.891000    7    0.2150   -12.237     1
#
#                                                      name  popularity  \
# 0                                Keep A Song In Your Soul          12
# 1                                    I Put A Spell On You           7
# 2                                            Golfing Papa           4
# 3       True House Music - Xavier Santos & Carlos Gomi...          17
# 4                                               Xuniverxe           2
# ...                                                   ...         ...
# 174384                                            The One           0
# 174385                                      A Little More           0
# 174386                                           Together           0
# 174387                                 champagne problems          69
# 174388                                     Improvisations           0
#
#        release_date  speechiness    tempo  valence  year
# 0              1920       0.0936  149.976   0.6340  1920
# 1        1920-01-05       0.0534   86.889   0.9500  1920
# 2              1920       0.1740   97.600   0.6890  1920
# 3        1920-01-01       0.0425  127.997   0.0422  1920
# 4        1920-10-01       0.0768  122.076   0.2990  1920
# ...             ...          ...      ...      ...   ...
# 174384   2020-12-25       0.0356  125.972   0.1860  2020
# 174385   2021-01-22       0.0360   94.710   0.2280  2021
# 174386   2020-12-09       0.0282  108.058   0.7140  2020
# 174387   2021-01-07       0.0377  171.319   0.3200  2021
# 174388   2020-12-09       0.0258  112.208   0.7470  2020
#
# [174389 rows x 19 columns]

# %% [markdown]
# ## Transforming the Data

# %% [markdown]
# The next three lines of code were to strip all the brackets, single and double quotes from the song titles

# %%
spotify_data['artists'] = spotify_data['artists'].str.strip('[]')

# %%
spotify_data['artists'] = spotify_data['artists'].str.strip("''")

# %%
spotify_data['artists'] = spotify_data['artists'].str.strip('""')

# %%
#checking to see that the strip worked
spotify_data
# Out:
#         acousticness                         artists  danceability  \
# 0           0.991000                     Mamie Smith         0.598
# 1           0.643000           Screamin' Jay Hawkins         0.852
# 2           0.993000                     Mamie Smith         0.647
# 3           0.000173                 Oscar Velazquez         0.730
# 4           0.295000                            Mixe         0.704
# ...              ...                             ...           ...
# 174384      0.009170  DJ Combo', 'Sander-7', 'Tony T         0.792
# 174385      0.795000                    Alessia Cara         0.429
# 174386      0.806000                       Roger Fly         0.671
# 174387      0.920000                    Taylor Swift         0.462
# 174388      0.239000                       Roger Fly         0.677
#
#         duration_ms  energy  explicit                      id  \
# 0            168333   0.224         0  0cS0A1fUEUd1EW3FcF8AEI
# 1            150200   0.517         0  0hbkKFIJm7Z05H8Zl9w30f
# 2            163827   0.186         0  11m7laMUgmOKqI3oYzuhne
# 3            422087   0.798         0  19Lc5SfJJ5O1oaxY0fpwfh
# 4            165224   0.707         1  2hJjbsLCytGsnAHfdsLejp
# ...             ...     ...       ...                     ...
# 174384       147615   0.866         0  46LhBf6TvYjZU2SMvGZAbn
# 174385       144720   0.211         0  7tue2Wemjd0FZzRtDrQFZd
# 174386       218147   0.589         0  48Qj61hOdYmUCFJbpQ29Ob
# 174387       244000   0.240         1  1gcyHQpBQ1lfXGdhZmWrHP
# 174388       197710   0.460         0  57tgYkWQTNHVFEt6xDKKZj
#
#         instrumentalness  key  liveness  loudness  mode  \
# 0               0.000522    5    0.3790   -12.628     0
# 1               0.026400    5    0.0809    -7.261     0
# 2               0.000018    0    0.5190   -12.098     1
# 3               0.801000    2    0.1280    -7.311     1
# 4               0.000246   10    0.4020    -6.036     0
# ...                  ...  ...       ...       ...   ...
# 174384          0.000060    6    0.1780    -5.089     0
# 174385          0.000000    4    0.1960   -11.665     1
# 174386          0.920000    4    0.1130   -12.393     0
# 174387          0.000000    0    0.1130   -12.077     1
# 174388          0.891000    7    0.2150   -12.237     1
#
#                                                      name  popularity  \
# 0                                Keep A Song In Your Soul          12
# 1                                    I Put A Spell On You           7
# 2                                            Golfing Papa           4
# 3       True House Music - Xavier Santos & Carlos Gomi...          17
# 4                                               Xuniverxe           2
# ...                                                   ...         ...
# 174384                                            The One           0
# 174385                                      A Little More           0
# 174386                                           Together           0
# 174387                                 champagne problems          69
# 174388                                     Improvisations           0
#
#        release_date  speechiness    tempo  valence  year
# 0              1920       0.0936  149.976   0.6340  1920
# 1        1920-01-05       0.0534   86.889   0.9500  1920
# 2              1920       0.1740   97.600   0.6890  1920
# 3        1920-01-01       0.0425  127.997   0.0422  1920
# 4        1920-10-01       0.0768  122.076   0.2990  1920
# ...             ...          ...      ...      ...   ...
# 174384   2020-12-25       0.0356  125.972   0.1860  2020
# 174385   2021-01-22       0.0360   94.710   0.2280  2021
# 174386   2020-12-09       0.0282  108.058   0.7140  2020
# 174387   2021-01-07       0.0377  171.319   0.3200  2021
# 174388   2020-12-09       0.0258  112.208   0.7470  2020
#
# [174389 rows x 19 columns]

# %% [markdown]
# The id was changed to spotify_song_id for clarity later when the other data sets get added. The name was changed to song_title to work with the other data sets

# %%
spotify_df = spotify_data.rename(columns={"id": "spotify_song_id", "name": "song_title"})
spotify_df
# Out:
#         acousticness                         artists  danceability  \
# 0           0.991000                     Mamie Smith         0.598
# 1           0.643000           Screamin' Jay Hawkins         0.852
# 2           0.993000                     Mamie Smith         0.647
# 3           0.000173                 Oscar Velazquez         0.730
# 4           0.295000                            Mixe         0.704
# ...              ...                             ...           ...
# 174384      0.009170  DJ Combo', 'Sander-7', 'Tony T         0.792
# 174385      0.795000                    Alessia Cara         0.429
# 174386      0.806000                       Roger Fly         0.671
# 174387      0.920000                    Taylor Swift         0.462
# 174388      0.239000                       Roger Fly         0.677
#
#         duration_ms  energy  explicit         spotify_song_id  \
# 0            168333   0.224         0  0cS0A1fUEUd1EW3FcF8AEI
# 1            150200   0.517         0  0hbkKFIJm7Z05H8Zl9w30f
# 2            163827   0.186         0  11m7laMUgmOKqI3oYzuhne
# 3            422087   0.798         0  19Lc5SfJJ5O1oaxY0fpwfh
# 4            165224   0.707         1  2hJjbsLCytGsnAHfdsLejp
# ...             ...     ...       ...                     ...
# 174384       147615   0.866         0  46LhBf6TvYjZU2SMvGZAbn
# 174385       144720   0.211         0  7tue2Wemjd0FZzRtDrQFZd
# 174386       218147   0.589         0  48Qj61hOdYmUCFJbpQ29Ob
# 174387       244000   0.240         1  1gcyHQpBQ1lfXGdhZmWrHP
# 174388       197710   0.460         0  57tgYkWQTNHVFEt6xDKKZj
#
#         instrumentalness  key  liveness  loudness  mode  \
# 0               0.000522    5    0.3790   -12.628     0
# 1               0.026400    5    0.0809    -7.261     0
# 2               0.000018    0    0.5190   -12.098     1
# 3               0.801000    2    0.1280    -7.311     1
# 4               0.000246   10    0.4020    -6.036     0
# ...                  ...  ...       ...       ...   ...
# 174384          0.000060    6    0.1780    -5.089     0
# 174385          0.000000    4    0.1960   -11.665     1
# 174386          0.920000    4    0.1130   -12.393     0
# 174387          0.000000    0    0.1130   -12.077     1
# 174388          0.891000    7    0.2150   -12.237     1
#
#                                                song_title  popularity  \
# 0                                Keep A Song In Your Soul          12
# 1                                    I Put A Spell On You           7
# 2                                            Golfing Papa           4
# 3       True House Music - Xavier Santos & Carlos Gomi...          17
# 4                                               Xuniverxe           2
# ...                                                   ...         ...
# 174384                                            The One           0
# 174385                                      A Little More           0
# 174386                                           Together           0
# 174387                                 champagne problems          69
# 174388                                     Improvisations           0
#
#        release_date  speechiness    tempo  valence  year
# 0              1920       0.0936  149.976   0.6340  1920
# 1        1920-01-05       0.0534   86.889   0.9500  1920
# 2              1920       0.1740   97.600   0.6890  1920
# 3        1920-01-01       0.0425  127.997   0.0422  1920
# 4        1920-10-01       0.0768  122.076   0.2990  1920
# ...             ...          ...      ...      ...   ...
# 174384   2020-12-25       0.0356  125.972   0.1860  2020
# 174385   2021-01-22       0.0360   94.710   0.2280  2021
# 174386   2020-12-09       0.0282  108.058   0.7140  2020
# 174387   2021-01-07       0.0377  171.319   0.3200  2021
# 174388   2020-12-09       0.0258  112.208   0.7470  2020
#
# [174389 rows x 19 columns]

# %% [markdown]
# The columns were re-organized to be more readable

# %%
spotify_df = spotify_df[["spotify_song_id","year","artists","song_title","release_date", "duration_ms", "acousticness", "danceability","energy","explicit", "instrumentalness", "key", "liveness", "loudness", "mode", "popularity", "speechiness", "tempo", "valence"]]
spotify_df.head()
# Out:
#           spotify_song_id  year                artists  \
# 0  0cS0A1fUEUd1EW3FcF8AEI  1920            Mamie Smith
# 1  0hbkKFIJm7Z05H8Zl9w30f  1920  Screamin' Jay Hawkins
# 2  11m7laMUgmOKqI3oYzuhne  1920            Mamie Smith
# 3  19Lc5SfJJ5O1oaxY0fpwfh  1920        Oscar Velazquez
# 4  2hJjbsLCytGsnAHfdsLejp  1920                   Mixe
#
#                                           song_title release_date  \
# 0                           Keep A Song In Your Soul         1920
# 1                               I Put A Spell On You   1920-01-05
# 2                                       Golfing Papa         1920
# 3  True House Music - Xavier Santos & Carlos Gomi...   1920-01-01
# 4                                          Xuniverxe   1920-10-01
#
#    duration_ms  acousticness  danceability  energy  explicit  \
# 0       168333      0.991000         0.598   0.224         0
# 1       150200      0.643000         0.852   0.517         0
# 2       163827      0.993000         0.647   0.186         0
# 3       422087      0.000173         0.730   0.798         0
# 4       165224      0.295000         0.704   0.707         1
#
#    instrumentalness  key  liveness  loudness  mode  popularity  speechiness  \
# 0          0.000522    5    0.3790   -12.628     0          12       0.0936
# 1          0.026400    5    0.0809    -7.261     0           7       0.0534
# 2          0.000018    0    0.5190   -12.098     1           4       0.1740
# 3          0.801000    2    0.1280    -7.311     1          17       0.0425
# 4          0.000246   10    0.4020    -6.036     0           2       0.0768
#
#      tempo  valence
# 0  149.976   0.6340
# 1   86.889   0.9500
# 2   97.600   0.6890
# 3  127.997   0.0422
# 4  122.076   0.2990

# %% [markdown]
# We decided to focus on only 10 years worth of data, so the spotify list was sorted to songs released after 2008. The other data sets were from 2009 to 2019, but the Spotify list was set to include 2008. This decision was made due to the fact that the songs on the Billboard chart at the beginning of 2009 would be from 2008. The cut off year of 2020 was given as well as the Grammy and Billboard data only went to 2019

# %%
spotify_last_10years = spotify_df.loc[(spotify_df["year"] >= 2008) & (spotify_df["year"] < 2020)]
spotify_last_10years
# Out:
#                spotify_song_id  year                 artists  \
# 9071    6catF1lDhNTjjGa2GxRQNN  2008  Gerry & The Pacemakers
# 9081    4aSw1QJIMwYSoDEgzgdCJL  2008  Gerry & The Pacemakers
# 9085    0ZMMtH875IR2TfkyC4PolD  2008  Gerry & The Pacemakers
# 9087    1hx7X9cMXHWJjknb9O6Ava  2018           Frank Sinatra
# 9091    19oquvXf3bc65GSqtPYA5S  2018           Frank Sinatra
# ...                        ...   ...                     ...
# 174116  4ZzfKwqPfy02fpQxuh9Zz3  2019          Workout Music
# 174118  3O1lskEk6MF8bEQ76Q7Cmv  2019          Workout Music
# 174120  4fBQiIB6X7sE5RWK7mZq8N  2019          Workout Music
# 174124  1g6Zm6BiN3WktHGzu0ZKAh  2013                 October
# 174128  7iqCw8dAglSWcXXne7RBlf  2019             DJ X-Change
#
#                                                song_title release_date  \
# 9071        You'll Never Walk Alone - Mono; 2002 Remaster   2008-02-11
# 9081         Ferry Cross the Mersey - Mono; 2002 Remaster   2008-02-11
# 9085     Don't Let the Sun Catch You Crying (Main) - Mono   2008-02-11
# 9087    The September Of My Years - Live At The Sands ...   2018-05-04
# 9091    It Was A Very Good Year - Live At The Sands Ho...   2018-05-04
# ...                                                   ...          ...
# 174116                  RITMO (Bay Boys For Life) [Remix]   2019-12-26
# 174118                           Beautiful People (Remix)   2019-12-26
# 174120                                       Tusa (Remix)   2019-12-26
# 174124                      A Good Year - 2020 Remastered         2013
# 174128              New Years Eve Ultimate Countdown 2020   2019-12-16
#
#         duration_ms  acousticness  danceability  energy  explicit  \
# 9071         160187       0.39400         0.484   0.265         0
# 9081         141987       0.25500         0.405   0.365         0
# 9085         157093       0.40600         0.477   0.352         0
# 9087         187333       0.88700         0.319   0.201         0
# 9091         236800       0.93800         0.269   0.129         0
# ...             ...           ...           ...     ...       ...
# 174116       277493       0.01380         0.734   0.809         0
# 174118       287987       0.06540         0.533   0.879         0
# 174120       268120       0.00358         0.764   0.828         0
# 174124       226603       0.98100         0.520   0.198         0
# 174128        30250       0.77200         0.620   0.475         0
#
#         instrumentalness  key  liveness  loudness  mode  popularity  \
# 9071            0.000000    0    0.1490   -11.101     1          55
# 9081            0.000005    6    0.1630   -10.226     0          39
# 9085            0.000000    1    0.1220   -14.165     1          34
# 9087            0.000000    7    0.9040   -17.796     1          27
# 9091            0.000005    7    0.6830   -18.168     0          26
# ...                  ...  ...       ...       ...   ...         ...
# 174116          0.012600    0    0.0635    -5.655     0          14
# 174118          0.000000    5    0.0147    -3.736     1          14
# 174120          0.005500    2    0.0763    -3.625     1          16
# 174124          0.909000    1    0.1020   -23.823     1           5
# 174128          0.000000    0    0.5080    -8.180     1           8
#
#         speechiness    tempo  valence
# 9071         0.0322  113.564    0.285
# 9081         0.0289  104.536    0.588
# 9085         0.0300  106.773    0.478
# 9087         0.0623  117.153    0.239
# 9091         0.0576   82.332    0.160
# ...             ...      ...      ...
# 174116       0.1150  128.015    0.965
# 174118       0.0492  129.943    0.398
# 174120       0.0810  127.994    0.931
# 174124       0.0483  123.976    0.272
# 174128       0.5410   93.056    0.321
#
# [25697 rows x 19 columns]

# %% [markdown]
# The column for duration_ms was going to be changed to a time, so that it was easier to understand. However, when attempting to import the data into SQL, it did not like the format. SQL attempted to force it back to ms. The conversion messed up duration as now every value for duration had an extra four zeroes on the end. This change was scrapped.

# %%
#unused duration to time change
# spotify_last_10years["duration_ms"] = pd.to_timedelta(spotify_last_10years["duration_ms"], unit='ms')
#spotify_last_10years.head()

# %% [markdown]
# Each song has a unqiue Spotify song id, and it was presumed that each ID was only used once. However, after some data exploration and issues with SQL, it was discovered that there were in fact duplicates. A group by the song_id, showed there were several duplicated song_ids listed.

# %%
groups = spotify_last_10years.groupby(['spotify_song_id'])
groups.count()
# Out:
#                         year  artists  song_title  release_date  duration_ms  \
# spotify_song_id
# 0025JMWRhsWx0GXdlzhHMO     1        1           1             1            1
# 002sGwDZYna3CKXbYIilHz     1        1           1             1            1
# 005lwxGU1tms6HGELIcUv9     1        1           1             1            1
# 006bxORtP7mtwDtULXaQqG     1        1           1             1            1
# 009ImBOrIUlWgla8U05RAC     1        1           1             1            1
# ...                      ...      ...         ...           ...          ...
# 7zvFLwOTZX18ImGiKrfyzw     1        1           1             1            1
# 7zwn1eykZtZ5LODrf7c0tS     1        1           1             1            1
# 7zxRMhXxJMQCeDDg0rKAVo     1        1           1             1            1
# 7zxv7kFipfmvpDiC1eU4Fb     1        1           1             1            1
# 7zyMIkp9d6JIu368q6PL2U     1        1           1             1            1
#
#                         acousticness  danceability  energy  explicit  \
# spotify_song_id
# 0025JMWRhsWx0GXdlzhHMO             1             1       1         1
# 002sGwDZYna3CKXbYIilHz             1             1       1         1
# 005lwxGU1tms6HGELIcUv9             1             1       1         1
# 006bxORtP7mtwDtULXaQqG             1             1       1         1
# 009ImBOrIUlWgla8U05RAC             1             1       1         1
# ...                              ...           ...     ...       ...
# 7zvFLwOTZX18ImGiKrfyzw             1             1       1         1
# 7zwn1eykZtZ5LODrf7c0tS             1             1       1         1
# 7zxRMhXxJMQCeDDg0rKAVo             1             1       1         1
# 7zxv7kFipfmvpDiC1eU4Fb             1             1       1         1
# 7zyMIkp9d6JIu368q6PL2U             1             1       1         1
#
#                         instrumentalness  key  liveness  loudness  mode  \
# spotify_song_id
# 0025JMWRhsWx0GXdlzhHMO                 1    1         1         1     1
# 002sGwDZYna3CKXbYIilHz                 1    1         1         1     1
# 005lwxGU1tms6HGELIcUv9                 1    1         1         1     1
# 006bxORtP7mtwDtULXaQqG                 1    1         1         1     1
# 009ImBOrIUlWgla8U05RAC                 1    1         1         1     1
# ...                                  ...  ...       ...       ...   ...
# 7zvFLwOTZX18ImGiKrfyzw                 1    1         1         1     1
# 7zwn1eykZtZ5LODrf7c0tS                 1    1         1         1     1
# 7zxRMhXxJMQCeDDg0rKAVo                 1    1         1         1     1
# 7zxv7kFipfmvpDiC1eU4Fb                 1    1         1         1     1
# 7zyMIkp9d6JIu368q6PL2U                 1    1         1         1     1
#
#                         popularity  speechiness  tempo  valence
# spotify_song_id
# 0025JMWRhsWx0GXdlzhHMO           1            1      1        1
# 002sGwDZYna3CKXbYIilHz           1            1      1        1
# 005lwxGU1tms6HGELIcUv9           1            1      1        1
# 006bxORtP7mtwDtULXaQqG           1            1      1        1
# 009ImBOrIUlWgla8U05RAC           1            1      1        1
# ...                            ...          ...    ...      ...
# 7zvFLwOTZX18ImGiKrfyzw           1            1      1        1
# 7zwn1eykZtZ5LODrf7c0tS           1            1      1        1
# 7zxRMhXxJMQCeDDg0rKAVo           1            1      1        1
# 7zxv7kFipfmvpDiC1eU4Fb           1            1      1        1
# 7zyMIkp9d6JIu368q6PL2U           1            1      1        1
#
# [24765 rows x 18 columns]

# %% [markdown]
# A drop duplicates function was used on the spotify_song_id to get rid of all duplicated songs.

# %%
spotify_last_10years = spotify_last_10years.drop_duplicates(subset=['spotify_song_id'])
spotify_last_10years
# Out:
#                spotify_song_id  year                 artists  \
# 9071    6catF1lDhNTjjGa2GxRQNN  2008  Gerry & The Pacemakers
# 9081    4aSw1QJIMwYSoDEgzgdCJL  2008  Gerry & The Pacemakers
# 9085    0ZMMtH875IR2TfkyC4PolD  2008  Gerry & The Pacemakers
# 9087    1hx7X9cMXHWJjknb9O6Ava  2018           Frank Sinatra
# 9091    19oquvXf3bc65GSqtPYA5S  2018           Frank Sinatra
# ...                        ...   ...                     ...
# 174116  4ZzfKwqPfy02fpQxuh9Zz3  2019          Workout Music
# 174118  3O1lskEk6MF8bEQ76Q7Cmv  2019          Workout Music
# 174120  4fBQiIB6X7sE5RWK7mZq8N  2019          Workout Music
# 174124  1g6Zm6BiN3WktHGzu0ZKAh  2013                 October
# 174128  7iqCw8dAglSWcXXne7RBlf  2019             DJ X-Change
#
#                                                song_title release_date  \
# 9071        You'll Never Walk Alone - Mono; 2002 Remaster   2008-02-11
# 9081         Ferry Cross the Mersey - Mono; 2002 Remaster   2008-02-11
# 9085     Don't Let the Sun Catch You Crying (Main) - Mono   2008-02-11
# 9087    The September Of My Years - Live At The Sands ...   2018-05-04
# 9091    It Was A Very Good Year - Live At The Sands Ho...   2018-05-04
# ...                                                   ...          ...
# 174116                  RITMO (Bay Boys For Life) [Remix]   2019-12-26
# 174118                           Beautiful People (Remix)   2019-12-26
# 174120                                       Tusa (Remix)   2019-12-26
# 174124                      A Good Year - 2020 Remastered         2013
# 174128              New Years Eve Ultimate Countdown 2020   2019-12-16
#
#         duration_ms  acousticness  danceability  energy  explicit  \
# 9071         160187       0.39400         0.484   0.265         0
# 9081         141987       0.25500         0.405   0.365         0
# 9085         157093       0.40600         0.477   0.352         0
# 9087         187333       0.88700         0.319   0.201         0
# 9091         236800       0.93800         0.269   0.129         0
# ...             ...           ...           ...     ...       ...
# 174116       277493       0.01380         0.734   0.809         0
# 174118       287987       0.06540         0.533   0.879         0
# 174120       268120       0.00358         0.764   0.828         0
# 174124       226603       0.98100         0.520   0.198         0
# 174128        30250       0.77200         0.620   0.475         0
#
#         instrumentalness  key  liveness  loudness  mode  popularity  \
# 9071            0.000000    0    0.1490   -11.101     1          55
# 9081            0.000005    6    0.1630   -10.226     0          39
# 9085            0.000000    1    0.1220   -14.165     1          34
# 9087            0.000000    7    0.9040   -17.796     1          27
# 9091            0.000005    7    0.6830   -18.168     0          26
# ...                  ...  ...       ...       ...   ...         ...
# 174116          0.012600    0    0.0635    -5.655     0          14
# 174118          0.000000    5    0.0147    -3.736     1          14
# 174120          0.005500    2    0.0763    -3.625     1          16
# 174124          0.909000    1    0.1020   -23.823     1           5
# 174128          0.000000    0    0.5080    -8.180     1           8
#
#         speechiness    tempo  valence
# 9071         0.0322  113.564    0.285
# 9081         0.0289  104.536    0.588
# 9085         0.0300  106.773    0.478
# 9087         0.0623  117.153    0.239
# 9091         0.0576   82.332    0.160
# ...             ...      ...      ...
# 174116       0.1150  128.015    0.965
# 174118       0.0492  129.943    0.398
# 174120       0.0810  127.994    0.931
# 174124       0.0483  123.976    0.272
# 174128       0.5410   93.056    0.321
#
# [24765 rows x 19 columns]

# %% [markdown]
# Saving the cleaned dataframe to a csv file

# %%
spotify_last_10years.to_csv("Resources/spotify_last_10years.csv", index=False, header=True)

# %% [markdown]
# A list of the columns was made to assist with putting all of the data into SQL.

# %%
list(spotify_last_10years.columns)
# Out:
# ['spotify_song_id',
#  'year',
#  'artists',
#  'song_title',
#  'release_date',
#  'duration_ms',
#  'acousticness',
#  'danceability',
#  'energy',
#  'explicit',
#  'instrumentalness',
#  'key',
#  'liveness',
#  'loudness',
#  'mode',
#  'popularity',
#  'speechiness',
#  'tempo',
#  'valence']

# %% [markdown]
# ## Loading the Data into SQL
# The table for the data has been set up in pgAdmin in a database called "music_DB" with a table called Spotify.
# After the data was loaded, the table was read through SQLAlchemy to verify the was properly added.

# %%
#Connection to SQL is made using music_db as the database
# rds_connection_string = f"{key}@localhost:5432/music_db"
# engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
#finding the table made in SQL
engine.table_names()
# Out:
# ['spotify', 'billboard', 'grammys']

# %%
#adding the data to the table in SQL
spotify_last_10years.to_sql(name='spotify', con=engine, if_exists='replace', index=False)

# %%
#verifying the data was made in SQL
pd.read_sql_query('select * from spotify', con=engine).head()
# Out:
#           spotify_song_id  year                 artists  \
# 0  6catF1lDhNTjjGa2GxRQNN  2008  Gerry & The Pacemakers
# 1  4aSw1QJIMwYSoDEgzgdCJL  2008  Gerry & The Pacemakers
# 2  0ZMMtH875IR2TfkyC4PolD  2008  Gerry & The Pacemakers
# 3  1hx7X9cMXHWJjknb9O6Ava  2018           Frank Sinatra
# 4  19oquvXf3bc65GSqtPYA5S  2018           Frank Sinatra
#
#                                           song_title release_date  \
# 0      You'll Never Walk Alone - Mono; 2002 Remaster   2008-02-11
# 1       Ferry Cross the Mersey - Mono; 2002 Remaster   2008-02-11
# 2   Don't Let the Sun Catch You Crying (Main) - Mono   2008-02-11
# 3  The September Of My Years - Live At The Sands ...   2018-05-04
# 4  It Was A Very Good Year - Live At The Sands Ho...   2018-05-04
#
#    duration_ms  acousticness  danceability  energy  explicit  \
# 0       160187         0.394         0.484   0.265         0
# 1       141987         0.255         0.405   0.365         0
# 2       157093         0.406         0.477   0.352         0
# 3       187333         0.887         0.319   0.201         0
# 4       236800         0.938         0.269   0.129         0
#
#    instrumentalness  key  liveness  loudness  mode  popularity  speechiness  \
# 0          0.000000    0     0.149   -11.101     1          55       0.0322
# 1          0.000005    6     0.163   -10.226     0          39       0.0289
# 2          0.000000    1     0.122   -14.165     1          34       0.0300
# 3          0.000000    7     0.904   -17.796     1          27       0.0623
# 4          0.000005    7     0.683   -18.168     0          26       0.0576
#
#      tempo  valence
# 0  113.564    0.285
# 1  104.536    0.588
# 2  106.773    0.478
# 3  117.153    0.239
# 4   82.332    0.160

# %% [markdown]
# <h1>Final Database</h1>

# %% [markdown]
# Querying all three tables from SQL database.  There are many options as to how to join the data; we chose to start from the Billboard table, and join to the Grammys and then the Spotify table to show one example of what could be gleaned from this dataset.

# %%
song_list = pd.read_sql_query("SELECT b.artists, b.song_title, b.genre, b.week, b.weeks_on_chart, g.year, g.category, g.winner, s.danceability, s.energy, s.popularity \
FROM billboard as b \
JOIN grammys as g ON g.nominee = b.song_title AND g.artist = b.artists \
JOIN spotify as s ON s.song_title = b.song_title AND s.artists=b.artists", con=engine)

# %%
song_list
# Out:
#           artists   song_title          genre       week  weeks_on_chart  \
# 0       Lady Gaga   Poker Face  Dance-Pop,Pop 2009-10-01            40.0
# 1       Lady Gaga   Poker Face  Dance-Pop,Pop 2009-09-24            39.0
# 2       Lady Gaga   Poker Face  Dance-Pop,Pop 2009-09-17            38.0
# 3       Lady Gaga   Poker Face  Dance-Pop,Pop 2009-09-10            37.0
# 4       Lady Gaga   Poker Face  Dance-Pop,Pop 2009-09-03            36.0
# ...           ...          ...            ...        ...             ...
# 1471  Keith Urban  Sweet Thing   Country,Rock 2009-01-29            10.0
# 1472  Keith Urban  Sweet Thing   Country,Rock 2009-01-22             9.0
# 1473  Keith Urban  Sweet Thing   Country,Rock 2009-01-15             8.0
# 1474  Keith Urban  Sweet Thing   Country,Rock 2009-01-08             7.0
# 1475  Keith Urban  Sweet Thing   Country,Rock 2009-01-01             6.0
#
#       year                             category  winner  danceability  energy  \
# 0     2009                 Best Dance Recording    True         0.851   0.806
# 1     2009                 Best Dance Recording    True         0.851   0.806
# 2     2009                 Best Dance Recording    True         0.851   0.806
# 3     2009                 Best Dance Recording    True         0.851   0.806
# 4     2009                 Best Dance Recording    True         0.851   0.806
# ...    ...                                  ...     ...           ...     ...
# 1471  2009  Best Male Country Vocal Performance    True         0.621   0.888
# 1472  2009  Best Male Country Vocal Performance    True         0.621   0.888
# 1473  2009  Best Male Country Vocal Performance    True         0.621   0.888
# 1474  2009  Best Male Country Vocal Performance    True         0.621   0.888
# 1475  2009  Best Male Country Vocal Performance    True         0.621   0.888
#
#       popularity
# 0             71
# 1             71
# 2             71
# 3             71
# 4             71
# ...          ...
# 1471          45
# 1472          45
# 1473          45
# 1474          45
# 1475          45
#
# [1476 rows x 11 columns]

# %%
# Added to prove that there are other years than just 2009
song_list.loc[song_list["year"]==2015]
# Out:
#               artists  song_title  \
# 391   Little Big Town  Girl Crush
# 392   Little Big Town  Girl Crush
# 393   Little Big Town  Girl Crush
# 394   Little Big Town  Girl Crush
# 395   Little Big Town  Girl Crush
# 396   Little Big Town  Girl Crush
# 397   Little Big Town  Girl Crush
# 398   Little Big Town  Girl Crush
# 399   Little Big Town  Girl Crush
# 400   Little Big Town  Girl Crush
# 401   Little Big Town  Girl Crush
# 402   Little Big Town  Girl Crush
# 403   Little Big Town  Girl Crush
# 404   Little Big Town  Girl Crush
# 405   Little Big Town  Girl Crush
# 406   Little Big Town  Girl Crush
# 407   Little Big Town  Girl Crush
# 408   Little Big Town  Girl Crush
# 409   Little Big Town  Girl Crush
# 410   Little Big Town  Girl Crush
# 411   Little Big Town  Girl Crush
# 412   Little Big Town  Girl Crush
# 413   Little Big Town  Girl Crush
# 414   Little Big Town  Girl Crush
# 415    Kendrick Lamar     Alright
# 416    Kendrick Lamar     Alright
# 417    Kendrick Lamar     Alright
# 418    Kendrick Lamar     Alright
# 419    Kendrick Lamar     Alright
# 420    Kendrick Lamar     Alright
# 421    Kendrick Lamar     Alright
# 422    Kendrick Lamar     Alright
# 423    Kendrick Lamar     Alright
# 424    Kendrick Lamar     Alright
# 425    Kendrick Lamar     Alright
# 426    Kendrick Lamar     Alright
# 427    Kendrick Lamar     Alright
# 428    Kendrick Lamar     Alright
# 1104  Chris Stapleton   Traveller
# 1105  Chris Stapleton   Traveller
#
#                                                   genre       week  \
# 391                                 Ballad,Country,Rock 2015-08-14
# 392                                 Ballad,Country,Rock 2015-08-07
# 393                                 Ballad,Country,Rock 2015-07-31
# 394                                 Ballad,Country,Rock 2015-07-24
# 395                                 Ballad,Country,Rock 2015-07-17
# 396                                 Ballad,Country,Rock 2015-07-10
# 397                                 Ballad,Country,Rock 2015-07-03
# 398                                 Ballad,Country,Rock 2015-06-26
# 399                                 Ballad,Country,Rock 2015-06-19
# 400                                 Ballad,Country,Rock 2015-06-12
# 401                                 Ballad,Country,Rock 2015-06-05
# 402                                 Ballad,Country,Rock 2015-05-29
# 403                                 Ballad,Country,Rock 2015-05-22
# 404                                 Ballad,Country,Rock 2015-05-15
# 405                                 Ballad,Country,Rock 2015-05-08
# 406                                 Ballad,Country,Rock 2015-05-01
# 407                                 Ballad,Country,Rock 2015-04-24
# 408                                 Ballad,Country,Rock 2015-04-17
# 409                                 Ballad,Country,Rock 2015-04-10
# 410                                 Ballad,Country,Rock 2015-04-03
# 411                                 Ballad,Country,Rock 2015-03-27
# 412                                 Ballad,Country,Rock 2015-03-20
# 413                                 Ballad,Country,Rock 2015-03-13
# 414                                 Ballad,Country,Rock 2015-02-20
# 415   Hip-Hop,Pop,Politics,Screen,Producer,Post-Bop,... 2015-10-09
# 416   Hip-Hop,Pop,Politics,Screen,Producer,Post-Bop,... 2015-10-02
# 417   Hip-Hop,Pop,Politics,Screen,Producer,Post-Bop,... 2015-09-25
# 418   Hip-Hop,Pop,Politics,Screen,Producer,Post-Bop,... 2015-09-18
# 419   Hip-Hop,Pop,Politics,Screen,Producer,Post-Bop,... 2015-09-11
# 420   Hip-Hop,Pop,Politics,Screen,Producer,Post-Bop,... 2015-09-04
# 421   Hip-Hop,Pop,Politics,Screen,Producer,Post-Bop,... 2015-08-28
# 422   Hip-Hop,Pop,Politics,Screen,Producer,Post-Bop,... 2015-08-21
# 423   Hip-Hop,Pop,Politics,Screen,Producer,Post-Bop,... 2015-08-14
# 424   Hip-Hop,Pop,Politics,Screen,Producer,Post-Bop,... 2015-08-07
# 425   Hip-Hop,Pop,Politics,Screen,Producer,Post-Bop,... 2015-07-31
# 426   Hip-Hop,Pop,Politics,Screen,Producer,Post-Bop,... 2015-07-24
# 427   Hip-Hop,Pop,Politics,Screen,Producer,Post-Bop,... 2015-07-17
# 428   Hip-Hop,Pop,Politics,Screen,Producer,Post-Bop,... 2015-04-03
# 1104                                            Country 2015-11-27
# 1105                                            Country 2015-11-27
#
#       weeks_on_chart  year                            category  winner  \
# 391             24.0  2015  Best Country Duo/Group Performance    True
# 392             23.0  2015  Best Country Duo/Group Performance    True
# 393             22.0  2015  Best Country Duo/Group Performance    True
# 394             21.0  2015  Best Country Duo/Group Performance    True
# 395             20.0  2015  Best Country Duo/Group Performance    True
# 396             19.0  2015  Best Country Duo/Group Performance    True
# 397             18.0  2015  Best Country Duo/Group Performance    True
# 398             17.0  2015  Best Country Duo/Group Performance    True
# 399             16.0  2015  Best Country Duo/Group Performance    True
# 400             15.0  2015  Best Country Duo/Group Performance    True
# 401             14.0  2015  Best Country Duo/Group Performance    True
# 402             13.0  2015  Best Country Duo/Group Performance    True
# 403             12.0  2015  Best Country Duo/Group Performance    True
# 404             11.0  2015  Best Country Duo/Group Performance    True
# 405             10.0  2015  Best Country Duo/Group Performance    True
# 406              9.0  2015  Best Country Duo/Group Performance    True
# 407              8.0  2015  Best Country Duo/Group Performance    True
# 408              7.0  2015  Best Country Duo/Group Performance    True
# 409              6.0  2015  Best Country Duo/Group Performance    True
# 410              5.0  2015  Best Country Duo/Group Performance    True
# 411              4.0  2015  Best Country Duo/Group Performance    True
# 412              3.0  2015  Best Country Duo/Group Performance    True
# 413              2.0  2015  Best Country Duo/Group Performance    True
# 414              NaN  2015  Best Country Duo/Group Performance    True
# 415             14.0  2015                Best Rap Performance    True
# 416             13.0  2015                Best Rap Performance    True
# 417             12.0  2015                Best Rap Performance    True
# 418             11.0  2015                Best Rap Performance    True
# 419             10.0  2015                Best Rap Performance    True
# 420              9.0  2015                Best Rap Performance    True
# 421              8.0  2015                Best Rap Performance    True
# 422              7.0  2015                Best Rap Performance    True
# 423              6.0  2015                Best Rap Performance    True
# 424              5.0  2015                Best Rap Performance    True
# 425              4.0  2015                Best Rap Performance    True
# 426              3.0  2015                Best Rap Performance    True
# 427              2.0  2015                Best Rap Performance    True
# 428              NaN  2015                Best Rap Performance    True
# 1104             NaN  2015                  Best Country Album    True
# 1105             NaN  2015       Best Country Solo Performance    True
#
#       danceability  energy  popularity
# 391          0.500   0.225          69
# 392          0.500   0.225          69
# 393          0.500   0.225          69
# 394          0.500   0.225          69
# 395          0.500   0.225          69
# 396          0.500   0.225          69
# 397          0.500   0.225          69
# 398          0.500   0.225          69
# 399          0.500   0.225          69
# 400          0.500   0.225          69
# 401          0.500   0.225          69
# 402          0.500   0.225          69
# 403          0.500   0.225          69
# 404          0.500   0.225          69
# 405          0.500   0.225          69
# 406          0.500   0.225          69
# 407          0.500   0.225          69
# 408          0.500   0.225          69
# 409          0.500   0.225          69
# 410          0.500   0.225          69
# 411          0.500   0.225          69
# 412          0.500   0.225          69
# 413          0.500   0.225          69
# 414          0.500   0.225          69
# 415          0.796   0.766          73
# 416          0.796   0.766          73
# 417          0.796   0.766          73
# 418          0.796   0.766          73
# 419          0.796   0.766          73
# 420          0.796   0.766          73
# 421          0.796   0.766          73
# 422          0.796   0.766          73
# 423          0.796   0.766          73
# 424          0.796   0.766          73
# 425          0.796   0.766          73
# 426          0.796   0.766          73
# 427          0.796   0.766          73
# 428          0.796   0.766          73
# 1104         0.543   0.750          64
# 1105         0.543   0.750          64

# %% [markdown]
# # Thoughts for Future Analysis

# %% [markdown]
# * This data could be used to potentially make a flask page where a person could query a song from 2009 to 2019 and find out what kind of song it is. Was the song on the Billboard charts? Did it have any award nominations? Is the song danceable?
#
# * The data can also be analyzed to find out if there are any trends in the type of songs that win song of the year or hit number 1 on the Billboard charts multiple weeks in a row.
#
# * We could look at the genres that are most popular versus those that win awards, and how that has changed over time.
#
# * We kept the data intact as not all songs on Billboard or Spotify are nominated for Grammys, and not necessarily all Grammy awards and nominations make the Billboard charts.  Someone wishing to look at the correlation of Billboard and Spotify popularity versus Grammy awards could do further analysis.
#
# * There is much more data in the Spotify table that could be joined to achieve deeper analysis regarding music trends.
